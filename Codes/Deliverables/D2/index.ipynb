# %% [markdown]
# # Deliverable #2
#
# The second deliverable that will also, once again, serve as a practical activity. This lesson is connected to the 3rd lesson, which is about Deep Convoluted Neural Network (DCNN).
#
# **Instructions**
#
# Download the [CIFAR-10](https://paperswithcode.com/dataset/cifar-10) dataset from any dataset repository. The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.
#
# Then train a convolutional neural network model. Also, explore and tweak the model by using Regularization techniques. Show the performance of the model using model history line plot and the classification evaluation using confusion matrix.
#
# Write a report containing the Classification Result. Submit the report file named as D2_LastName.pdf and a zip file named as D2_LastName.zip containing your code.

# %% [markdown]
# ## Imports
#
# All needed libraries will be imported here.
#
# Unless conditional, all imports must be done in this section to prevent workspace cluttering. Imports are sorted in an ascending manner, starting from "a" to "Z".

# %%
from sklearn.metrics import confusion_matrix
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, ReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model, to_categorical
import datetime
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import random
import seaborn as sns
import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# ## Data and Variable
#
# Sets all the global data and variables here.
#
# Global variables will be defined and instantiated in this section, preventing a confusing clutter down the line and allowing readability when revisions are needed.

# %% [markdown]
# ### Instantiations
#
# Instantiations of variables will be done here, preventing mixture of variable preview and definition.

# %% [markdown]
# #### Variables

# %%
try:
    if os is None or EarlyStopping is None or ReduceLROnPlateau is None:
        raise ImportError("os, EarlyStopping, or ReduceLROnPlateau module not found")
except NameError:
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
    import os

data = {
    "train": {
        "raw": [os.path.join('data', file) for file in os.listdir("data") if file.startswith('data_batch_')],
        "loaded": {},
        "processed": None
    },
    "test": {
        "raw": os.path.join('data', 'test_batch'),
        "loaded": {},
        "processed": None
    },
    "meta": os.path.join('data', 'batches.meta')
}
"""
A dictionary to hold the data for the CIFAR-10 dataset.
The dictionary contains the following keys:

- train: A dictionary containing the training data. It has two keys:
    - raw: A list of file paths for the training data files.
    - loaded: A dictionary to hold the loaded training data.
    - processed: A dictionary to hold the processed training data.
- test: A dictionary containing the test data. It has two keys:
    - raw: The file path for the test data file.
    - loaded: A dictionary to hold the loaded test data.
    - processed: A dictionary to hold the processed test data.
- meta: The file path for the metadata file.

:var data: dict
"""

callbacks = [
    EarlyStopping(
        monitor = 'val_loss',
        patience = 10,
        verbose = 2,
        restore_best_weights = True
    ),
    ReduceLROnPlateau(
        monitor = 'val_loss',
        factor = 0.5,
        patience = 5,
        verbose = 2,
        min_lr = 1e-6
    )
]
"""
A list of callbacks for the model training. Currently, it contains
the following callbacks:
- EarlyStopping: Stops training when a monitored metric has stopped improving.
"""

None

# %% [markdown]
# #### Functions

# %%
def unpickle(file):
    """
    Decompiles a pickle file.

    :param file: Path to the pickle file.
    :type file: str
    
    :return: The unpickled data.
    :rtype: dict
    """
    global pickle
    try:
        pickle
    except NameError:
        import pickle

    if not os.path.isfile(file):
        raise FileNotFoundError(f"File {file} not found.")
    
    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data

def unpickleToTuple(file):
    """
    Decompiles a pickle file into a tuple. The tuple
    contains the `data` and `labels` keys from the unpickled data
    in that respective order.

    The `data` key contains the image data and the `labels` key
    contains the labels for the images.

    The `data` key is a numpy array of shape (n, 3072) where n is the
    number of images. The `labels` key is a list of length n containing
    the labels for the images.

    :param file: Path to the pickle file.
    :type file: str
    
    :return: The unpickled data as a tuple.
    :rtype: tuple
    """
    data = unpickle(file)
    return (data[b'data'], data[b'labels'])

def showImg(input, title = None, axis = False):
    """
    Displays an image.

    :param input: The image to display.
    :type input: numpy.ndarray
    
    :param title: Title of the image.
    :type title: str

    :param axis: Whether to show the axis or not.
    :type axis: bool
    """
    global plt
    if plt is None:
        import matplotlib.pyplot as plt
    plt.imshow(input)
    if title is not None:
        plt.title(title)
    if not axis:
        plt.axis('off')
    plt.show()

None

# %% [markdown]
# ### Previews

# %%
print(f"Training data files: {data['train']['raw']}")
print(f"Testing data file: {data['test']['raw']}")
print(f"Meta data file: {data['meta']}")
# Out:
# Training data files: ['data\\data_batch_1', 'data\\data_batch_2', 'data\\data_batch_3', 'data\\data_batch_4', 'data\\data_batch_5']
# Testing data file: data\test_batch
# Meta data file: data\batches.meta

# %%
try:
    random
except NameError:
    import random

for file in data['train']["raw"]:
    print(f"Unpickling {file}...")
    batch = unpickle(file)
    print(f"Unpickled {file} with keys: {batch.keys()}")
    print(f"Batch shape: {batch[b'data'].shape}")
    print(f"Labels shape: {len(batch[b'labels'])}")
    print(f"Batch size: {len(batch[b'data'])}")
    print(f"Batch content size: {len(batch[b'data'][random.randint(0, len(batch[b'data']) - 1)])}")
    print(f"Peek in the batch: {batch[b'data']}")
    print(f"Peek in the batch content: {batch[b'data'][random.randint(0, len(batch[b'data']) - 1)]}")
    print("==============================================")
    data['train']["loaded"][file] = batch
# Out:
# Unpickling data\data_batch_1...
# Unpickled data\data_batch_1 with keys: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# Batch shape: (10000, 3072)
# Labels shape: 10000
# Batch size: 10000
# Batch content size: 3072
# Peek in the batch: [[ 59  43  50 ... 140  84  72]
#  [154 126 105 ... 139 142 144]
#  [255 253 253 ...  83  83  84]
#  ...
#  [ 71  60  74 ...  68  69  68]
#  [250 254 211 ... 215 255 254]
#  [ 62  61  60 ... 130 130 131]]
# Peek in the batch content: [240 233 233 ... 114 106 125]
# ==============================================
# Unpickling data\data_batch_2...
# Unpickled data\data_batch_2 with keys: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# Batch shape: (10000, 3072)
# Labels shape: 10000
# Batch size: 10000
# Batch content size: 3072
# Peek in the batch: [[ 35  27  25 ... 169 168 168]
#  [ 20  20  18 ... 111  97  51]
#  [116 115 155 ...  18  84 124]
#  ...
#  [127 139 155 ... 197 192 191]
#  [190 200 208 ... 163 182 192]
#  [177 174 182 ... 119 127 136]]
# Peek in the batch content: [174 177 209 ...  30  29  68]
# ==============================================
# Unpickling data\data_batch_3...
# Unpickled data\data_batch_3 with keys: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# Batch shape: (10000, 3072)
# Labels shape: 10000
# Batch size: 10000
# Batch content size: 3072
# Peek in the batch: [[ 26  17  13 ...  27  26  27]
#  [ 94 101  95 ... 182 184 155]
#  [183 158 166 ... 250 250 250]
#  ...
#  [175 200 207 ... 124  49  32]
#  [ 28  59  67 ...  36  44  41]
#  [ 62  40  61 ... 127 124 116]]
# Peek in the batch content: [184 183 183 ... 121 113 100]
# ==============================================
# Unpickling data\data_batch_4...
# Unpickled data\data_batch_4 with keys: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# Batch shape: (10000, 3072)
# Labels shape: 10000
# Batch size: 10000
# Batch content size: 3072
# Peek in the batch: [[178 178 178 ...  80  80  77]
#  [ 29  22  25 ...  29  31  30]
#  [ 36  33  21 ... 173 170 170]
#  ...
#  [167 164 151 ... 132 142 130]
#  [ 45  46  46 ...  30  34  24]
#  [235 239 239 ... 182 175 174]]
# Peek in the batch content: [ 60  93 135 ... 165 162 165]
# ==============================================
# Unpickling data\data_batch_5...
# Unpickled data\data_batch_5 with keys: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# Batch shape: (10000, 3072)
# Labels shape: 10000
# Batch size: 10000
# Batch content size: 3072
# Peek in the batch: [[255 252 253 ... 173 231 248]
#  [127 126 127 ... 102 108 112]
#  [116  64  19 ...   7   6   5]
#  ...
#  [ 35  40  42 ...  77  66  50]
#  [189 186 185 ... 169 171 171]
#  [229 236 234 ... 173 162 161]]
# Peek in the batch content: [74 85 91 ... 67 67 68]
# ==============================================

# %%
try:
    random
except NameError:
    import random

print(f"Unpickling {data['test']['raw']}...")
batch = unpickle(data['test']['raw'])
print(f"Unpickled {data['test']['raw']} with keys: {batch.keys()}")
print(f"Batch shape: {batch[b'data'].shape}")
print(f"Labels shape: {len(batch[b'labels'])}")
print(f"Batch size: {len(batch[b'data'])}")
print(f"Batch content size: {len(batch[b'data'][random.randint(0, len(batch[b'data']) - 1)])}")
print(f"Peek in the batch: {batch[b'data']}")
print(f"Peek in the batch content: {batch[b'data'][random.randint(0, len(batch[b'data']) - 1)]}")
print("==============================================")
data['test']["loaded"] = batch
# Out:
# Unpickling data\test_batch...
# Unpickled data\test_batch with keys: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# Batch shape: (10000, 3072)
# Labels shape: 10000
# Batch size: 10000
# Batch content size: 3072
# Peek in the batch: [[158 159 165 ... 124 129 110]
#  [235 231 232 ... 178 191 199]
#  [158 158 139 ...   8   3   7]
#  ...
#  [ 20  19  15 ...  50  53  47]
#  [ 25  15  23 ...  80  81  80]
#  [ 73  98  99 ...  94  58  26]]
# Peek in the batch content: [222 218 214 ...  38  56  82]
# ==============================================

# %%
data['meta'] = unpickle(data['meta'])
data['meta']
# Out:
# {b'num_cases_per_batch': 10000,
#  b'label_names': [b'airplane',
#   b'automobile',
#   b'bird',
#   b'cat',
#   b'deer',
#   b'dog',
#   b'frog',
#   b'horse',
#   b'ship',
#   b'truck'],
#  b'num_vis': 3072}

# %%
data['train']['loaded'][f'data\\data_batch_{random.randint(1, 5)}']
# Out:
# {b'batch_label': b'training batch 1 of 5',
#  b'labels': [6,
#   9,
#   9,
#   4,
#   1,
#   1,
#   2,
#   7,
#   8,
#   3,
#   4,
#   7,
#   7,
#   2,
#   9,
#   9,
#   9,
#   3,
#   2,
#   6,
#   4,
#   3,
#   6,
#   6,
#   2,
#   6,
#   3,
#   5,
#   4,
#   0,
#   0,
#   9,
#   1,
#   3,
#   4,
#   0,
#   3,
#   7,
#   3,
#   3,
#   5,
#   2,
#   2,
#   7,
#   1,
#   1,
#   1,
#   2,
#   2,
#   0,
#   9,
#   5,
#   7,
#   9,
#   2,
#   2,
#   5,
#   2,
#   4,
#   3,
#   1,
#   1,
#   8,
#   2,
#   1,
#   1,
#   4,
#   9,
#   7,
#   8,
#   5,
#   9,
#   6,
#   7,
#   3,
#   1,
#   9,
#   0,
#   3,
#   1,
#   3,
#   5,
#   4,
#   5,
#   7,
#   7,
#   4,
#   7,
#   9,
#   4,
#   2,
#   3,
#   8,
#   0,
#   1,
#   6,
#   1,
#   1,
#   4,
#   1,
#   8,
#   3,
#   9,
#   6,
#   6,
#   1,
#   8,
#   5,
#   2,
#   9,
#   9,
#   8,
#   1,
#   7,
#   7,
#   0,
#   0,
#   6,
#   9,
#   1,
#   2,
#   2,
#   9,
#   2,
#   6,
#   6,
#   1,
#   9,
#   5,
#   0,
#   4,
#   7,
#   6,
#   7,
#   1,
#   8,
#   1,
#   1,
#   2,
#   8,
#   1,
#   3,
#   3,
#   6,
#   2,
#   4,
#   9,
#   9,
#   5,
#   4,
#   3,
#   6,
#   7,
#   4,
#   6,
#   8,
#   5,
#   5,
#   4,
#   3,
#   1,
#   8,
#   4,
#   7,
#   6,
#   0,
#   9,
#   5,
#   1,
#   3,
#   8,
#   2,
#   7,
#   5,
#   3,
#   4,
#   1,
#   5,
#   7,
#   0,
#   4,
#   7,
#   5,
#   5,
#   1,
#   0,
#   9,
#   6,
#   9,
#   0,
#   8,
#   7,
#   8,
#   8,
#   2,
#   5,
#   2,
#   3,
#   5,
#   0,
#   6,
#   1,
#   9,
#   3,
#   6,
#   9,
#   1,
#   3,
#   9,
#   6,
#   6,
#   7,
#   1,
#   0,
#   9,
#   5,
#   8,
#   5,
#   2,
#   9,
#   0,
#   8,
#   8,
#   0,
#   6,
#   9,
#   1,
#   1,
#   6,
#   3,
#   7,
#   6,
#   6,
#   0,
#   6,
#   6,
#   1,
#   7,
#   1,
#   5,
#   8,
#   3,
#   6,
#   6,
#   8,
#   6,
#   8,
#   4,
#   6,
#   6,
#   1,
#   3,
#   8,
#   3,
#   4,
#   1,
#   7,
#   1,
#   3,
#   8,
#   5,
#   1,
#   1,
#   4,
#   0,
#   9,
#   3,
#   7,
#   4,
#   9,
#   9,
#   2,
#   4,
#   9,
#   9,
#   1,
#   0,
#   5,
#   9,
#   0,
#   8,
#   2,
#   1,
#   2,
#   0,
#   5,
#   6,
#   3,
#   2,
#   7,
#   8,
#   8,
#   6,
#   0,
#   7,
#   9,
#   4,
#   5,
#   6,
#   4,
#   2,
#   1,
#   1,
#   2,
#   1,
#   5,
#   9,
#   9,
#   0,
#   8,
#   4,
#   1,
#   1,
#   6,
#   3,
#   3,
#   9,
#   0,
#   7,
#   9,
#   7,
#   7,
#   9,
#   1,
#   5,
#   1,
#   6,
#   6,
#   8,
#   7,
#   1,
#   3,
#   0,
#   3,
#   3,
#   2,
#   4,
#   5,
#   7,
#   5,
#   9,
#   0,
#   3,
#   4,
#   0,
#   4,
#   4,
#   6,
#   0,
#   0,
#   6,
#   6,
#   0,
#   8,
#   1,
#   6,
#   2,
#   9,
#   2,
#   5,
#   9,
#   6,
#   7,
#   4,
#   1,
#   8,
#   7,
#   3,
#   6,
#   9,
#   3,
#   0,
#   4,
#   0,
#   5,
#   1,
#   0,
#   3,
#   4,
#   8,
#   5,
#   4,
#   7,
#   2,
#   3,
#   9,
#   7,
#   6,
#   7,
#   1,
#   4,
#   7,
#   0,
#   1,
#   7,
#   3,
#   1,
#   8,
#   4,
#   4,
#   2,
#   0,
#   2,
#   2,
#   0,
#   0,
#   9,
#   0,
#   9,
#   6,
#   8,
#   2,
#   7,
#   7,
#   4,
#   0,
#   3,
#   0,
#   8,
#   9,
#   4,
#   2,
#   7,
#   2,
#   5,
#   2,
#   5,
#   1,
#   9,
#   4,
#   8,
#   5,
#   1,
#   7,
#   4,
#   4,
#   0,
#   6,
#   9,
#   0,
#   7,
#   8,
#   8,
#   9,
#   9,
#   3,
#   3,
#   4,
#   0,
#   4,
#   5,
#   6,
#   6,
#   0,
#   1,
#   0,
#   8,
#   0,
#   4,
#   8,
#   8,
#   1,
#   5,
#   2,
#   6,
#   8,
#   1,
#   0,
#   0,
#   7,
#   7,
#   5,
#   9,
#   6,
#   2,
#   8,
#   3,
#   4,
#   7,
#   3,
#   9,
#   0,
#   1,
#   2,
#   4,
#   8,
#   1,
#   8,
#   6,
#   4,
#   4,
#   5,
#   7,
#   1,
#   3,
#   9,
#   8,
#   0,
#   1,
#   7,
#   5,
#   8,
#   2,
#   8,
#   0,
#   4,
#   1,
#   8,
#   9,
#   8,
#   2,
#   9,
#   9,
#   2,
#   7,
#   5,
#   7,
#   3,
#   8,
#   8,
#   4,
#   4,
#   2,
#   7,
#   1,
#   6,
#   4,
#   0,
#   4,
#   6,
#   9,
#   7,
#   6,
#   2,
#   5,
#   5,
#   1,
#   7,
#   2,
#   2,
#   2,
#   9,
#   5,
#   4,
#   2,
#   7,
#   8,
#   1,
#   3,
#   4,
#   3,
#   7,
#   6,
#   9,
#   8,
#   0,
#   6,
#   0,
#   2,
#   2,
#   2,
#   1,
#   8,
#   4,
#   0,
#   1,
#   8,
#   8,
#   1,
#   5,
#   7,
#   6,
#   4,
#   5,
#   8,
#   7,
#   1,
#   9,
#   1,
#   9,
#   8,
#   4,
#   7,
#   3,
#   8,
#   8,
#   2,
#   6,
#   6,
#   7,
#   1,
#   6,
#   8,
#   1,
#   9,
#   7,
#   8,
#   3,
#   0,
#   1,
#   0,
#   8,
#   8,
#   3,
#   0,
#   0,
#   1,
#   5,
#   0,
#   8,
#   8,
#   7,
#   9,
#   9,
#   0,
#   9,
#   4,
#   1,
#   3,
#   6,
#   6,
#   4,
#   4,
#   7,
#   5,
#   6,
#   0,
#   8,
#   0,
#   3,
#   2,
#   8,
#   4,
#   6,
#   9,
#   9,
#   7,
#   0,
#   3,
#   3,
#   6,
#   7,
#   4,
#   9,
#   1,
#   6,
#   2,
#   7,
#   2,
#   2,
#   0,
#   6,
#   7,
#   5,
#   7,
#   6,
#   8,
#   9,
#   0,
#   9,
#   4,
#   4,
#   7,
#   0,
#   9,
#   4,
#   9,
#   6,
#   9,
#   4,
#   5,
#   7,
#   9,
#   2,
#   4,
#   5,
#   1,
#   4,
#   3,
#   9,
#   6,
#   5,
#   6,
#   9,
#   3,
#   3,
#   5,
#   0,
#   7,
#   2,
#   1,
#   3,
#   6,
#   4,
#   0,
#   0,
#   2,
#   5,
#   0,
#   1,
#   0,
#   2,
#   3,
#   9,
#   8,
#   4,
#   9,
#   8,
#   0,
#   2,
#   6,
#   4,
#   4,
#   0,
#   1,
#   8,
#   8,
#   3,
#   6,
#   9,
#   6,
#   6,
#   7,
#   8,
#   2,
#   4,
#   5,
#   7,
#   6,
#   5,
#   3,
#   0,
#   5,
#   0,
#   5,
#   0,
#   8,
#   2,
#   6,
#   7,
#   3,
#   8,
#   2,
#   1,
#   7,
#   6,
#   7,
#   1,
#   0,
#   9,
#   5,
#   5,
#   0,
#   1,
#   7,
#   6,
#   9,
#   0,
#   4,
#   7,
#   7,
#   1,
#   5,
#   9,
#   4,
#   0,
#   8,
#   5,
#   9,
#   9,
#   6,
#   7,
#   1,
#   8,
#   3,
#   2,
#   3,
#   8,
#   2,
#   2,
#   4,
#   6,
#   0,
#   0,
#   5,
#   3,
#   8,
#   2,
#   3,
#   7,
#   2,
#   9,
#   3,
#   8,
#   7,
#   8,
#   2,
#   7,
#   9,
#   0,
#   2,
#   3,
#   2,
#   2,
#   2,
#   3,
#   3,
#   6,
#   2,
#   3,
#   2,
#   8,
#   0,
#   5,
#   5,
#   1,
#   4,
#   5,
#   6,
#   6,
#   2,
#   7,
#   0,
#   1,
#   7,
#   7,
#   8,
#   2,
#   9,
#   2,
#   2,
#   4,
#   2,
#   1,
#   1,
#   1,
#   6,
#   6,
#   6,
#   5,
#   1,
#   1,
#   7,
#   0,
#   4,
#   3,
#   3,
#   7,
#   1,
#   2,
#   3,
#   5,
#   5,
#   5,
#   6,
#   1,
#   4,
#   3,
#   7,
#   8,
#   8,
#   3,
#   6,
#   6,
#   2,
#   3,
#   0,
#   9,
#   4,
#   3,
#   8,
#   0,
#   0,
#   1,
#   1,
#   5,
#   4,
#   9,
#   3,
#   1,
#   8,
#   9,
#   3,
#   9,
#   9,
#   2,
#   9,
#   4,
#   8,
#   2,
#   9,
#   8,
#   8,
#   1,
#   5,
#   3,
#   6,
#   8,
#   7,
#   6,
#   9,
#   8,
#   0,
#   6,
#   4,
#   0,
#   0,
#   2,
#   5,
#   8,
#   2,
#   0,
#   2,
#   7,
#   6,
#   9,
#   7,
#   1,
#   5,
#   5,
#   6,
#   6,
#   3,
#   6,
#   2,
#   4,
#   7,
#   0,
#   5,
#   6,
#   4,
#   6,
#   5,
#   2,
#   4,
#   6,
#   1,
#   6,
#   0,
#   4,
#   0,
#   3,
#   1,
#   8,
#   5,
#   4,
#   4,
#   1,
#   7,
#   3,
#   9,
#   4,
#   7,
#   9,
#   7,
#   3,
#   7,
#   2,
#   8,
#   4,
#   6,
#   6,
#   1,
#   2,
#   9,
#   0,
#   4,
#   8,
#   7,
#   3,
#   9,
#   8,
#   7,
#   7,
#   0,
#   2,
#   4,
#   1,
#   1,
#   4,
#   1,
#   5,
#   4,
#   0,
#   5,
#   6,
#   2,
#   8,
#   5,
#   0,
#   2,
#   1,
#   3,
#   5,
#   7,
#   3,
#   5,
#   1,
#   3,
#   5,
#   ...],
#  b'data': array([[ 59,  43,  50, ..., 140,  84,  72],
#         [154, 126, 105, ..., 139, 142, 144],
#         [255, 253, 253, ...,  83,  83,  84],
#         ...,
#         [ 71,  60,  74, ...,  68,  69,  68],
#         [250, 254, 211, ..., 215, 255, 254],
#         [ 62,  61,  60, ..., 130, 130, 131]], dtype=uint8),
#  b'filenames': [b'leptodactylus_pentadactylus_s_000004.png',
#   b'camion_s_000148.png',
#   b'tipper_truck_s_001250.png',
#   b'american_elk_s_001521.png',
#   b'station_wagon_s_000293.png',
#   b'coupe_s_001735.png',
#   b'cassowary_s_001300.png',
#   b'cow_pony_s_001168.png',
#   b'sea_boat_s_001584.png',
#   b'tabby_s_001355.png',
#   b'muntjac_s_001000.png',
#   b'arabian_s_001354.png',
#   b'quarter_horse_s_000672.png',
#   b'passerine_s_000343.png',
#   b'camion_s_001895.png',
#   b'trailer_truck_s_000335.png',
#   b'dumper_s_000821.png',
#   b'alley_cat_s_000200.png',
#   b'accentor_s_000677.png',
#   b'frog_s_001671.png',
#   b'capreolus_capreolus_s_000051.png',
#   b'tomcat_s_000772.png',
#   b'pickerel_frog_s_000446.png',
#   b'bufo_s_001242.png',
#   b'cassowary_s_001246.png',
#   b'toad_s_001748.png',
#   b'cat_s_000081.png',
#   b'chihuahua_s_000825.png',
#   b'alces_alces_s_000959.png',
#   b'stealth_bomber_s_000554.png',
#   b'twinjet_s_000663.png',
#   b'trucking_rig_s_001402.png',
#   b'auto_s_000609.png',
#   b'tabby_cat_s_000983.png',
#   b'wapiti_s_000416.png',
#   b'monoplane_s_000895.png',
#   b'true_cat_s_000247.png',
#   b'tennessee_walker_s_000486.png',
#   b'house_cat_s_000243.png',
#   b'house_cat_s_001196.png',
#   b'pekinese_s_001337.png',
#   b'ostrich_s_001368.png',
#   b'ostrich_s_001150.png',
#   b'stallion_s_000046.png',
#   b'station_waggon_s_000041.png',
#   b'coupe_s_001944.png',
#   b'estate_car_s_000580.png',
#   b'accentor_s_000759.png',
#   b'emu_novaehollandiae_s_000795.png',
#   b'dive_bomber_s_001390.png',
#   b'articulated_lorry_s_000131.png',
#   b'pekinese_s_001093.png',
#   b'broodmare_s_001463.png',
#   b'delivery_truck_s_000834.png',
#   b'songbird_s_001052.png',
#   b'emu_s_000692.png',
#   b'puppy_s_000115.png',
#   b'wagtail_s_001821.png',
#   b'dama_dama_s_000658.png',
#   b'domestic_cat_s_001970.png',
#   b'ambulance_s_003039.png',
#   b'convertible_s_001763.png',
#   b'tank_ship_s_001229.png',
#   b'cassowary_s_001055.png',
#   b'wagon_s_001142.png',
#   b'police_cruiser_s_000620.png',
#   b'moose_s_002308.png',
#   b'aerial_ladder_truck_s_000584.png',
#   b'saddle_horse_s_000717.png',
#   b'tanker_s_001350.png',
#   b'mongrel_s_001571.png',
#   b'truck_s_000835.png',
#   b'pickerel_frog_s_001195.png',
#   b'lipizzan_s_000399.png',
#   b'tabby_s_000074.png',
#   b'automobile_s_001887.png',
#   b'moving_van_s_001665.png',
#   b'attack_aircraft_s_000153.png',
#   b'domestic_cat_s_001596.png',
#   b'compact_car_s_000048.png',
#   b'domestic_cat_s_000009.png',
#   b'pekingese_s_002089.png',
#   b'capreolus_capreolus_s_001095.png',
#   b'blenheim_spaniel_s_001103.png',
#   b'stallion_s_000040.png',
#   b'stud_mare_s_001672.png',
#   b'elk_s_000920.png',
#   b'lipizzan_s_001123.png',
#   b'fire_truck_s_002721.png',
#   b'elk_s_001888.png',
#   b'finch_s_000750.png',
#   b'tabby_s_000880.png',
#   b'banana_boat_s_001324.png',
#   b'twinjet_s_000591.png',
#   b'shooting_brake_s_000029.png',
#   b'rana_pipiens_s_000101.png',
#   b'station_wagon_s_001387.png',
#   b'station_wagon_s_002712.png',
#   b'odocoileus_hemionus_s_000221.png',
#   b'convertible_s_001715.png',
#   b'abandoned_ship_s_000574.png',
#   b'true_cat_s_000114.png',
#   b'dustcart_s_000063.png',
#   b'frog_s_000797.png',
#   b'green_frog_s_001320.png',
#   b'compact_car_s_001038.png',
#   b'freighter_s_001351.png',
#   b'mutt_s_000251.png',
#   b'accentor_s_000303.png',
#   b'lorry_s_001154.png',
#   b'fire_truck_s_000894.png',
#   b'cargo_vessel_s_000731.png',
#   b'cruiser_s_000774.png',
#   b'lippizan_s_000359.png',
#   b'broodmare_s_001741.png',
#   b'fighter_aircraft_s_000876.png',
#   b'amphibious_aircraft_s_000216.png',
#   b'leopard_frog_s_000339.png',
#   b'trucking_rig_s_001315.png',
#   b'shooting_brake_s_000886.png',
#   b'pipit_s_000549.png',
#   b'ostrich_s_002148.png',
#   b'trucking_rig_s_001600.png',
#   b'alauda_arvensis_s_000755.png',
#   b'rana_temporaria_s_001087.png',
#   b'bufo_s_000136.png',
#   b'estate_car_s_000529.png',
#   b'aerial_ladder_truck_s_000997.png',
#   b'toy_spaniel_s_000384.png',
#   b'amphibious_aircraft_s_001195.png',
#   b'fallow_deer_s_001598.png',
#   b'quarter_horse_s_000414.png',
#   b'anuran_s_000712.png',
#   b'arabian_s_001366.png',
#   b'auto_s_000040.png',
#   b'cargo_ship_s_001063.png',
#   b'motorcar_s_000121.png',
#   b'motorcar_s_000305.png',
#   b'anthus_pratensis_s_001071.png',
#   b'cruiser_s_000294.png',
#   b'wagon_s_000763.png',
#   b'alley_cat_s_002579.png',
#   b'tabby_cat_s_000825.png',
#   b'spadefoot_s_000051.png',
#   b'wagtail_s_002075.png',
#   b'fallow_deer_s_001697.png',
#   b'garbage_truck_s_000777.png',
#   b'moving_van_s_000067.png',
#   b'mongrel_s_000696.png',
#   b'red_deer_s_000741.png',
#   b'true_cat_s_001768.png',
#   b'spadefoot_s_000377.png',
#   b'lipizzan_s_001233.png',
#   b'japanese_deer_s_000163.png',
#   b'toad_s_002436.png',
#   b'police_boat_s_001421.png',
#   b'puppy_s_002062.png',
#   b'lapdog_s_001869.png',
#   b'elk_s_001196.png',
#   b'domestic_cat_s_001235.png',
#   b'car_s_000057.png',
#   b'lightship_s_000064.png',
#   b'fallow_deer_s_001997.png',
#   b'quarter_horse_s_000022.png',
#   b'bufo_calamita_s_000566.png',
#   b'biplane_s_000624.png',
#   b'fire_truck_s_001616.png',
#   b'japanese_spaniel_s_000037.png',
#   b'ambulance_s_001394.png',
#   b'domestic_cat_s_001056.png',
#   b'tugboat_s_001384.png',
#   b'emu_s_000072.png',
#   b'gelding_s_000206.png',
#   b'puppy_s_000637.png',
#   b'tabby_cat_s_002607.png',
#   b'elk_s_001198.png',
#   b'estate_car_s_001496.png',
#   b'peke_s_001338.png',
#   b'arabian_s_001018.png',
#   b'fighter_aircraft_s_000538.png',
#   b'fallow_deer_s_001164.png',
#   b'lippizan_s_000390.png',
#   b'toy_dog_s_000932.png',
#   b'maltese_s_002151.png',
#   b'car_s_000002.png',
#   b'jumbo_jet_s_000697.png',
#   b'dump_truck_s_000008.png',
#   b'spadefoot_s_000084.png',
#   b'motortruck_s_000014.png',
#   b'jetliner_s_001502.png',
#   b'tanker_s_000157.png',
#   b'riding_horse_s_001870.png',
#   b'cabin_cruiser_s_000096.png',
#   b'dredger_s_001623.png',
#   b'pipit_s_001102.png',
#   b'mongrel_s_002430.png',
#   b'skylark_s_000150.png',
#   b'cat_s_001604.png',
#   b'puppy_s_000211.png',
#   b'airbus_s_001124.png',
#   b'leopard_frog_s_001021.png',
#   b'wagon_s_001824.png',
#   b'garbage_truck_s_000147.png',
#   b'tabby_s_001354.png',
#   b'rana_temporaria_s_000295.png',
#   b'lorry_s_000364.png',
#   b'estate_car_s_000075.png',
#   b'tabby_s_000970.png',
#   b'fire_engine_s_000985.png',
#   b'toad_s_000022.png',
#   b'texas_toad_s_000215.png',
#   b'broodmare_s_000707.png',
#   b'car_s_000286.png',
#   b'twinjet_s_000565.png',
#   b'truck_s_001385.png',
#   b'toy_dog_s_000752.png',
#   b'police_boat_s_000092.png',
#   b'toy_dog_s_001197.png',
#   b'cassowary_s_002446.png',
#   b'articulated_lorry_s_000050.png',
#   b'monoplane_s_000781.png',
#   b'lightship_s_000343.png',
#   b'powerboat_s_001486.png',
#   b'jumbo_jet_s_000071.png',
#   b'bufo_debilis_s_000024.png',
#   b'transporter_s_000272.png',
#   b'estate_car_s_000743.png',
#   b'motorcar_s_000697.png',
#   b'rana_catesbeiana_s_001655.png',
#   b'tabby_s_000675.png',
#   b'remount_s_000285.png',
#   b'rana_catesbeiana_s_001521.png',
#   b'true_frog_s_000223.png',
#   b'airliner_s_002304.png',
#   b'natterjack_s_000987.png',
#   b'leptodactylid_s_000082.png',
#   b'coupe_s_001892.png',
#   b'quarter_horse_s_000419.png',
#   b'car_s_001323.png',
#   b'maltese_dog_s_001043.png',
#   b'boat_s_000543.png',
#   b'tabby_cat_s_001537.png',
#   b'rana_catesbeiana_s_001096.png',
#   b'bufo_bufo_s_000326.png',
#   b'pilot_boat_s_000646.png',
#   b'toad_frog_s_001672.png',
#   b'boat_s_000988.png',
#   b'deer_s_001383.png',
#   b'bufo_bufo_s_000261.png',
#   b'leopard_frog_s_000763.png',
#   b'coupe_s_002178.png',
#   b'cat_s_000663.png',
#   b'ship_s_000175.png',
#   b'house_cat_s_001471.png',
#   b'stag_s_001458.png',
#   b'station_wagon_s_001337.png',
#   b'quarter_horse_s_002201.png',
#   b'coupe_s_000698.png',
#   b'tomcat_s_002553.png',
#   b'scow_s_001266.png',
#   b'chihuahua_s_000385.png',
#   b'convertible_s_001500.png',
#   b'convertible_s_000408.png',
#   b'odocoileus_hemionus_s_000512.png',
#   b'jumbo_jet_s_000971.png',
#   b'truck_s_000650.png',
#   b'domestic_cat_s_001288.png',
#   b'walking_horse_s_000194.png',
#   b'elk_s_001657.png',
#   b'tipper_truck_s_000287.png',
#   b'dumper_s_000648.png',
#   b'struthio_camelus_s_000225.png',
#   b'woodland_caribou_s_000803.png',
#   b'ladder_truck_s_000795.png',
#   b'pantechnicon_s_000230.png',
#   b'shooting_brake_s_000229.png',
#   b'jetliner_s_001349.png',
#   b'toy_dog_s_001280.png',
#   b'dump_truck_s_002104.png',
#   b'twinjet_s_001360.png',
#   b'tugboat_s_000715.png',
#   b'passerine_s_000360.png',
#   b'automobile_s_002337.png',
#   b'honey_eater_s_001422.png',
#   b'attack_aircraft_s_001304.png',
#   b'toy_dog_s_000114.png',
#   b'anuran_s_000550.png',
#   b'mouser_s_000382.png',
#   b'sparrow_s_000037.png',
#   b'stud_mare_s_001038.png',
#   b'speedboat_s_002588.png',
#   b'passenger_ship_s_002153.png',
#   b'bufo_bufo_s_001876.png',
#   b'biplane_s_000651.png',
#   b'gelding_s_001785.png',
#   b'trucking_rig_s_001598.png',
#   b'deer_s_000309.png',
#   b'pekingese_s_001946.png',
#   b'frog_s_002802.png',
#   b'cervus_unicolor_s_000290.png',
#   b'honey_eater_s_000478.png',
#   b'automobile_s_001152.png',
#   b'coupe_s_000846.png',
#   b'flying_bird_s_000252.png',
#   b'automobile_s_002343.png',
#   b'japanese_spaniel_s_001162.png',
#   b'fire_truck_s_000043.png',
#   b'semi_s_001207.png',
#   b'fighter_aircraft_s_001840.png',
#   b'ship_s_001976.png',
#   b'caribou_s_001222.png',
#   b'police_cruiser_s_001347.png',
#   b'coupe_s_000042.png',
#   b'bufo_bufo_s_000995.png',
#   b'tabby_s_001148.png',
#   b'true_cat_s_000476.png',
#   b'garbage_truck_s_001442.png',
#   b'fighter_aircraft_s_000385.png',
#   b'quarter_horse_s_001602.png',
#   b'camion_s_000116.png',
#   b'tennessee_walker_s_000539.png',
#   b'lipizzan_s_000452.png',
#   b'trucking_rig_s_001594.png',
#   b'shooting_brake_s_001611.png',
#   b'puppy_s_002096.png',
#   b'auto_s_000855.png',
#   b'bufo_marinus_s_001364.png',
#   b'natterjack_s_000036.png',
#   b'pontoon_s_000643.png',
#   b'stallion_s_001256.png',
#   b'coupe_s_001863.png',
#   b'house_cat_s_000079.png',
#   b'jetliner_s_000981.png',
#   b'felis_catus_s_000853.png',
#   b'tabby_cat_s_000827.png',
#   b'struthio_camelus_s_001250.png',
#   b'fawn_s_001915.png',
#   b'canis_familiaris_s_001298.png',
#   b'lipizzan_s_002122.png',
#   b'toy_spaniel_s_001133.png',
#   b'dump_truck_s_000029.png',
#   b'fighter_s_001042.png',
#   b'domestic_cat_s_000493.png',
#   b'cervus_elaphus_s_001764.png',
#   b'airbus_s_000627.png',
#   b'fawn_s_001452.png',
#   b'fallow_deer_s_000959.png',
#   b'spadefoot_s_000777.png',
#   b'seaplane_s_001639.png',
#   b'plane_s_001066.png',
#   b'bufo_viridis_s_000348.png',
#   b'crapaud_s_000051.png',
#   b'seaplane_s_001447.png',
#   b'boat_s_000404.png',
#   b'convertible_s_001242.png',
#   b'toad_s_000201.png',
#   b'finch_s_000494.png',
#   b'fire_engine_s_001437.png',
#   b'pipit_s_000226.png',
#   b'toy_dog_s_000960.png',
#   b'delivery_truck_s_001121.png',
#   b'bufo_marinus_s_001506.png',
#   b'studhorse_s_000010.png',
#   b'woodland_caribou_s_001003.png',
#   b'station_wagon_s_000260.png',
#   b'pilot_boat_s_000356.png',
#   b'stud_mare_s_001497.png',
#   b'tabby_cat_s_001966.png',
#   b'american_toad_s_000006.png',
#   b'tipper_s_000010.png',
#   b'tomcat_s_002230.png',
#   b'dive_bomber_s_001120.png',
#   b'wapiti_s_000802.png',
#   b'biplane_s_000862.png',
#   b'blenheim_spaniel_s_000589.png',
#   b'shooting_brake_s_001161.png',
#   b'jetliner_s_000400.png',
#   b'tabby_s_000923.png',
#   b'alces_alces_s_000361.png',
#   b'police_boat_s_000002.png',
#   b'mutt_s_001696.png',
#   b'cervus_elaphus_s_001695.png',
#   b'quarter_horse_s_000752.png',
#   b'accentor_s_000449.png',
#   b'tabby_cat_s_000144.png',
#   b'fire_engine_s_001513.png',
#   b'tennessee_walking_horse_s_001187.png',
#   b'bufo_s_001247.png',
#   b'arabian_s_002147.png',
#   b'compact_s_001258.png',
#   b'elk_s_002339.png',
#   b'stud_mare_s_001384.png',
#   b'fighter_aircraft_s_000745.png',
#   b'police_cruiser_s_001047.png',
#   b'lipizzan_s_001764.png',
#   b'cat_s_000331.png',
#   b'taxi_s_000701.png',
#   b'boat_s_000432.png',
#   b'japanese_deer_s_000942.png',
#   b'sambar_s_000076.png',
#   b'ostrich_s_001559.png',
#   b'dive_bomber_s_000185.png',
#   b'lark_s_001532.png',
#   b'flightless_bird_s_000480.png',
#   b'stealth_fighter_s_001312.png',
#   b'jumbojet_s_000789.png',
#   b'delivery_truck_s_000510.png',
#   b'biplane_s_001901.png',
#   b'lorry_s_001185.png',
#   b'crapaud_s_000511.png',
#   b'boat_s_001280.png',
#   b'bird_s_001357.png',
#   b'stud_mare_s_001477.png',
#   b'arabian_s_000751.png',
#   b'rangifer_caribou_s_000586.png',
#   b'monoplane_s_000036.png',
#   b'house_cat_s_001321.png',
#   b'stealth_fighter_s_000240.png',
#   b'oil_tanker_s_000129.png',
#   b'tipper_truck_s_000416.png',
#   b'roe_deer_s_000358.png',
#   b'rhea_americana_s_000475.png',
#   b'lippizaner_s_000517.png',
#   b'cassowary_s_000297.png',
#   b'pekingese_s_001675.png',
#   b'accentor_s_001058.png',
#   b'lapdog_s_000227.png',
#   b'auto_s_001153.png',
#   b'fire_engine_s_000443.png',
#   b'muntjac_s_000815.png',
#   b'lightship_s_000090.png',
#   b'dog_s_002441.png',
#   b'auto_s_001951.png',
#   b'arabian_s_000328.png',
#   b'odocoileus_hemionus_s_000188.png',
#   b'barking_deer_s_000019.png',
#   b'dive_bomber_s_001486.png',
#   b'bufo_viridis_s_000503.png',
#   b'wrecker_s_002294.png',
#   b'monoplane_s_000206.png',
#   b'arabian_s_002282.png',
#   b'speedboat_s_002160.png',
#   b'cargo_vessel_s_002136.png',
#   b'garbage_truck_s_000726.png',
#   b'delivery_truck_s_001468.png',
#   b'house_cat_s_002240.png',
#   b'house_cat_s_000045.png',
#   b'caribou_s_002007.png',
#   b'propeller_plane_s_000451.png',
#   b'fallow_deer_s_001082.png',
#   b'dog_s_001897.png',
#   b'bufo_bufo_s_001631.png',
#   b'spadefoot_s_000191.png',
#   b'multiengine_airplane_s_000186.png',
#   b'auto_s_002359.png',
#   b'stealth_bomber_s_001607.png',
#   b'passenger_ship_s_000582.png',
#   b'airliner_s_001297.png',
#   b'fallow_deer_s_000973.png',
#   b'speedboat_s_000178.png',
#   b'boat_s_001444.png',
#   b'estate_car_s_000712.png',
#   b'english_toy_spaniel_s_000888.png',
#   b'passerine_s_000699.png',
#   b'rana_pipiens_s_000286.png',
#   b'tanker_s_000025.png',
#   b'car_s_001956.png',
#   b'stealth_bomber_s_000424.png',
#   b'airliner_s_001070.png',
#   b'stud_mare_s_001348.png',
#   b'quarter_horse_s_000282.png',
#   b'maltese_s_001818.png',
#   b'lorry_s_001786.png',
#   b'true_frog_s_000064.png',
#   b'cassowary_s_001372.png',
#   b'houseboat_s_000626.png',
#   b'domestic_cat_s_000035.png',
#   b'deer_s_001596.png',
#   b'cow_pony_s_000803.png',
#   b'tabby_cat_s_001466.png',
#   b'tipper_truck_s_001525.png',
#   b'stealth_fighter_s_000533.png',
#   b'station_wagon_s_000750.png',
#   b'wagtail_s_001549.png',
#   b'rangifer_caribou_s_000985.png',
#   b'cargo_ship_s_000408.png',
#   b'cab_s_000788.png',
#   b'flatboat_s_000044.png',
#   b'bufo_viridis_s_000457.png',
#   b'fallow_deer_s_000040.png',
#   b'barren_ground_caribou_s_000077.png',
#   b'pekinese_s_000453.png',
#   b'female_horse_s_000358.png',
#   b'compact_car_s_000869.png',
#   b'tabby_cat_s_002454.png',
#   b'delivery_truck_s_000864.png',
#   b'cargo_ship_s_000802.png',
#   b'attack_aircraft_s_000037.png',
#   b'convertible_s_000037.png',
#   b'broodmare_s_001448.png',
#   b'toy_spaniel_s_001286.png',
#   b'packet_boat_s_001206.png',
#   b'ostrich_s_001564.png',
#   b'hospital_ship_s_001658.png',
#   b'stealth_bomber_s_001035.png',
#   b'stag_s_002583.png',
#   b'police_cruiser_s_000629.png',
#   b'merchant_ship_s_001242.png',
#   b'dump_truck_s_001584.png',
#   b'cargo_ship_s_001830.png',
#   b'nandu_s_000721.png',
#   b'garbage_truck_s_001119.png',
#   b'lorry_s_002317.png',
#   b'wagtail_s_001445.png',
#   b'lipizzan_s_002049.png',
#   b'maltese_s_000948.png',
#   b'quarter_horse_s_000798.png',
#   b'house_cat_s_001472.png',
#   b'tank_ship_s_001155.png',
#   b'hospital_ship_s_001838.png',
#   b'mule_deer_s_000581.png',
#   b'deer_s_001329.png',
#   b'rhea_americana_s_000268.png',
#   b'lippizan_s_000440.png',
#   b'convertible_s_002117.png',
#   b'bufo_marinus_s_001567.png',
#   b'roe_deer_s_000690.png',
#   b'twinjet_s_000481.png',
#   b'american_elk_s_001743.png',
#   b'bufo_viridis_s_000254.png',
#   b'dumper_s_000179.png',
#   b'lippizan_s_000323.png',
#   b'leopard_frog_s_000058.png',
#   b'prunella_modularis_s_000578.png',
#   b'maltese_s_001867.png',
#   b'toy_dog_s_001358.png',
#   b'police_cruiser_s_000500.png',
#   b'broodmare_s_001589.png',
#   b'passerine_s_000381.png',
#   b'accentor_s_000424.png',
#   b'finch_s_000617.png',
#   b'trucking_rig_s_001111.png',
#   b'canis_familiaris_s_001059.png',
#   b'cervus_elaphus_s_000813.png',
#   b'cassowary_s_000339.png',
#   b'buckskin_s_000325.png',
#   b'lightship_s_001019.png',
#   b'shooting_brake_s_001330.png',
#   b'tomcat_s_002649.png',
#   b'barren_ground_caribou_s_000174.png',
#   b'cat_s_000572.png',
#   b'walking_horse_s_002079.png',
#   b'rana_temporaria_s_001139.png',
#   b'tipper_s_000007.png',
#   b'freighter_s_000661.png',
#   b'stealth_fighter_s_000020.png',
#   b'goliath_frog_s_000205.png',
#   b'stealth_bomber_s_000703.png',
#   b'prunella_modularis_s_000795.png',
#   b'struthio_camelus_s_000331.png',
#   b'dunnock_s_000956.png',
#   b'auto_s_001284.png',
#   b'scow_s_000831.png',
#   b'fallow_deer_s_001256.png',
#   b'stealth_fighter_s_001297.png',
#   b'estate_car_s_000845.png',
#   b'ship_s_001691.png',
#   b'abandoned_ship_s_000977.png',
#   b'wagon_s_001298.png',
#   b'feist_s_000354.png',
#   b'lipizzan_s_001600.png',
#   b'leopard_frog_s_001700.png',
#   b'cervus_elaphus_s_000066.png',
#   b'toy_s_000517.png',
#   b'cargo_ship_s_000556.png',
#   b'stallion_s_001717.png',
#   b'coupe_s_001004.png',
#   b'camion_s_001068.png',
#   b'coupe_s_000001.png',
#   b'garbage_truck_s_001253.png',
#   b'sea_boat_s_001960.png',
#   b'capreolus_capreolus_s_001169.png',
#   b'lippizan_s_000681.png',
#   b'tabby_s_000512.png',
#   b'pontoon_s_000271.png',
#   b'sea_boat_s_001502.png',
#   b'lark_s_000700.png',
#   b'leopard_frog_s_001074.png',
#   b'rana_palustris_s_000022.png',
#   b'lippizaner_s_001181.png',
#   b'wagon_s_000155.png',
#   b'american_toad_s_001410.png',
#   b'cargo_vessel_s_000659.png',
#   b'station_wagon_s_001705.png',
#   b'transporter_s_000076.png',
#   b'broodmare_s_001098.png',
#   b'passenger_ship_s_000050.png',
#   b'tabby_cat_s_000484.png',
#   b'fighter_s_000276.png',
#   b'car_s_000506.png',
#   b'stealth_fighter_s_000139.png',
#   b'pleasure_craft_s_000076.png',
#   b'cruiser_s_000744.png',
#   b'tabby_cat_s_002478.png',
#   b'attack_aircraft_s_000423.png',
#   b'stealth_fighter_s_000460.png',
#   b'police_cruiser_s_000787.png',
#   b'mongrel_s_000381.png',
#   b'attack_aircraft_s_001166.png',
#   b'supertanker_s_000557.png',
#   b'tugboat_s_000807.png',
#   b'stud_mare_s_000413.png',
#   b'lorry_s_001039.png',
#   b'trailer_truck_s_001496.png',
#   b'airliner_s_001477.png',
#   b'camion_s_001521.png',
#   b'alces_alces_s_000404.png',
#   b'automobile_s_000315.png',
#   b'tabby_cat_s_001542.png',
#   b'pickerel_frog_s_000003.png',
#   b'spring_frog_s_000318.png',
#   b'roebuck_s_000153.png',
#   b'reindeer_s_000121.png',
#   b'male_horse_s_000008.png',
#   b'dog_s_000052.png',
#   b'bufo_bufo_s_001959.png',
#   b'stealth_bomber_s_000492.png',
#   b'pilot_boat_s_001819.png',
#   b'attack_aircraft_s_001187.png',
#   b'house_cat_s_000812.png',
#   b'cassowary_s_000138.png',
#   b'boat_s_000490.png',
#   b'wapiti_s_000884.png',
#   b'bufo_bufo_s_001492.png',
#   b'delivery_truck_s_000157.png',
#   b'truck_s_000060.png',
#   b'stud_mare_s_000506.png',
#   b'fighter_aircraft_s_000655.png',
#   b'true_cat_s_000127.png',
#   b'tabby_s_000228.png',
#   b'american_green_toad_s_000007.png',
#   b'quarter_horse_s_001833.png',
#   b'odocoileus_hemionus_s_001090.png',
#   b'tipper_lorry_s_000527.png',
#   b'compact_car_s_001200.png',
#   b'pickerel_frog_s_000242.png',
#   b'finch_s_000308.png',
#   b'arabian_s_002456.png',
#   b'dunnock_s_001476.png',
#   b'emu_s_002196.png',
#   b'plane_s_000065.png',
#   b'european_toad_s_000360.png',
#   b'arabian_s_002383.png',
#   b'dog_s_002098.png',
#   b'quarter_horse_s_001757.png',
#   b'rana_temporaria_s_001922.png',
#   b'cargo_ship_s_001318.png',
#   b'tip_truck_s_001017.png',
#   b'biplane_s_001055.png',
#   b'camion_s_001255.png',
#   b'red_deer_s_000756.png',
#   b'capreolus_capreolus_s_000822.png',
#   b'lippizaner_s_000840.png',
#   b'propeller_plane_s_001438.png',
#   b'dumper_s_000646.png',
#   b'capreolus_capreolus_s_000284.png',
#   b'truck_s_000526.png',
#   b'bufo_s_001473.png',
#   b'fire_engine_s_001449.png',
#   b'elk_s_001164.png',
#   b'canis_familiaris_s_001319.png',
#   b'tennessee_walking_horse_s_000005.png',
#   b'truck_s_000838.png',
#   b'rhea_s_001649.png',
#   b'mule_deer_s_002514.png',
#   b'canis_familiaris_s_000143.png',
#   b'police_cruiser_s_001073.png',
#   b'cervus_sika_s_000273.png',
#   b'cat_s_001584.png',
#   b'tipper_lorry_s_000313.png',
#   b'bufo_americanus_s_001202.png',
#   b'english_toy_spaniel_s_000735.png',
#   b'bufo_calamita_s_000043.png',
#   b'tipper_s_000180.png',
#   b'tabby_cat_s_000881.png',
#   b'tabby_cat_s_001644.png',
#   b'blenheim_spaniel_s_000330.png',
#   b'attack_aircraft_s_001138.png',
#   b'arabian_s_002270.png',
#   b'cassowary_s_000845.png',
#   b'wagon_s_000692.png',
#   b'tabby_cat_s_000319.png',
#   b'american_toad_s_000077.png',
#   b'moose_s_001500.png',
#   b'airliner_s_001406.png',
#   b'fighter_aircraft_s_000966.png',
#   b'dunnock_s_000055.png',
#   b'pekingese_s_002399.png',
#   b'twinjet_s_000739.png',
#   b'automobile_s_002249.png',
#   b'airliner_s_000669.png',
#   b'wagtail_s_001656.png',
#   b'tabby_s_001949.png',
#   b'dump_truck_s_001009.png',
#   b'freighter_s_000436.png',
#   b'fallow_deer_s_001171.png',
#   b'trucking_rig_s_000684.png',
#   b'ship_s_000249.png',
#   b'monoplane_s_000416.png',
#   b'songbird_s_002066.png',
#   b'rana_catesbeiana_s_000602.png',
#   b'red_deer_s_000536.png',
#   b'elk_s_001583.png',
#   b'stealth_fighter_s_001313.png',
#   b'station_wagon_s_002498.png',
#   b'pleasure_boat_s_001949.png',
#   b'cargo_ship_s_000060.png',
#   b'tabby_cat_s_001767.png',
#   b'crapaud_s_000055.png',
#   b'dump_truck_s_002008.png',
#   b'bufo_viridis_s_000506.png',
#   b'bullfrog_s_001295.png',
#   b'riding_horse_s_001884.png',
#   b'boat_s_002344.png',
#   b'ostrich_s_000950.png',
#   b'muntjac_s_000681.png',
#   b'pekingese_s_000279.png',
#   b'lipizzan_s_002052.png',
#   b'rana_pipiens_s_000570.png',
#   b'toy_s_002250.png',
#   b'tabby_s_001940.png',
#   b'dive_bomber_s_001294.png',
#   b'mutt_s_000086.png',
#   b'biplane_s_000701.png',
#   b'toy_s_000964.png',
#   b'jetliner_s_000807.png',
#   b'barge_s_000426.png',
#   b'cassowary_s_000255.png',
#   b'rana_clamitans_s_000059.png',
#   b'quarter_horse_s_000222.png',
#   b'tomcat_s_000377.png',
#   b'scow_s_000687.png',
#   b'emu_s_001571.png',
#   b'coupe_s_001625.png',
#   b'roan_s_000199.png',
#   b'bufo_bufo_s_000626.png',
#   b'tennessee_walking_horse_s_001470.png',
#   b'station_wagon_s_001497.png',
#   b'jumbo_jet_s_001056.png',
#   b'trailer_truck_s_000099.png',
#   b'puppy_s_000502.png',
#   b'pekingese_s_002101.png',
#   b'propeller_plane_s_001193.png',
#   b'car_s_001009.png',
#   b'lipizzan_s_002011.png',
#   b'green_frog_s_001375.png',
#   b'tipper_lorry_s_000586.png',
#   b'jetliner_s_000509.png',
#   b'musk_deer_s_000211.png',
#   b'appaloosa_s_002251.png',
#   b'arabian_s_001642.png',
#   b'compact_car_s_000435.png',
#   b'chihuahua_s_000063.png',
#   b'semi_s_000462.png',
#   b'wapiti_s_000455.png',
#   b'twinjet_s_001120.png',
#   b'cargo_vessel_s_001235.png',
#   b'peke_s_000274.png',
#   b'dump_truck_s_001422.png',
#   b'dump_truck_s_001863.png',
#   b'tailed_frog_s_000638.png',
#   b'gelding_s_000965.png',
#   b'coupe_s_000056.png',
#   b'pleasure_craft_s_000625.png',
#   b'house_cat_s_001328.png',
#   b'struthio_camelus_s_000081.png',
#   b'domestic_cat_s_000051.png',
#   b'passenger_ship_s_000948.png',
#   b'sparrow_s_002697.png',
#   b'prunella_modularis_s_000302.png',
#   b'fallow_deer_s_000192.png',
#   b'rana_palustris_s_000107.png',
#   b'attack_aircraft_s_001075.png',
#   b'twinjet_s_000046.png',
#   b'chihuahua_s_001038.png',
#   b'tabby_cat_s_001004.png',
#   b'cargo_vessel_s_001812.png',
#   b'dunnock_s_000037.png',
#   b'tabby_s_001740.png',
#   b'gelding_s_001638.png',
#   b'anthus_pratensis_s_001166.png',
#   b'camion_s_001988.png',
#   b'alley_cat_s_001645.png',
#   b'oil_tanker_s_001626.png',
#   b'tennessee_walking_horse_s_000355.png',
#   b'containership_s_000812.png',
#   b'passerine_s_000801.png',
#   b'lipizzan_s_000635.png',
#   b'truck_s_000635.png',
#   b'twinjet_s_000450.png',
#   b'honey_eater_s_000702.png',
#   b'tabby_s_000039.png',
#   b'pipit_s_000827.png',
#   b'elephant_bird_s_001004.png',
#   b'night_bird_s_000241.png',
#   b'alley_cat_s_001301.png',
#   b'house_cat_s_000332.png',
#   b'bufo_americanus_s_000492.png',
#   b'wagtail_s_001443.png',
#   b'tabby_cat_s_000587.png',
#   b'gamecock_s_000098.png',
#   b'cargo_ship_s_001867.png',
#   b'seaplane_s_000416.png',
#   b'english_toy_spaniel_s_001058.png',
#   b'japanese_spaniel_s_001324.png',
#   b'coupe_s_000179.png',
#   b'american_elk_s_000201.png',
#   b'chihuahua_s_000666.png',
#   b'spadefoot_s_000219.png',
#   b'bufo_s_001733.png',
#   b'struthio_camelus_s_001368.png',
#   b'arab_s_000456.png',
#   b'monoplane_s_001154.png',
#   b'coupe_s_001690.png',
#   b'dawn_horse_s_000752.png',
#   b'tennessee_walking_horse_s_000013.png',
#   b'cabin_cruiser_s_001500.png',
#   b'sparrow_s_001750.png',
#   b'aerial_ladder_truck_s_001306.png',
#   b'dromaius_novaehollandiae_s_000433.png',
#   b'passerine_s_000376.png',
#   b'caribou_s_001447.png',
#   b'bird_s_000356.png',
#   b'motorcar_s_001389.png',
#   b'auto_s_000675.png',
#   b'automobile_s_001833.png',
#   b'rana_temporaria_s_000008.png',
#   b'spring_frog_s_001263.png',
#   b'barking_frog_s_000397.png',
#   b'puppy_s_000785.png',
#   b'convertible_s_001861.png',
#   b'convertible_s_000859.png',
#   b'american_saddle_horse_s_000039.png',
#   b'biplane_s_000244.png',
#   b'red_deer_s_000704.png',
#   b'tabby_s_001071.png',
#   b'tabby_cat_s_002548.png',
#   b'tennessee_walker_s_001791.png',
#   b'auto_s_002048.png',
#   b'dromaius_novaehollandiae_s_000296.png',
#   b'felis_catus_s_001460.png',
#   b'peke_s_000440.png',
#   b'chihuahua_s_000349.png',
#   b'lapdog_s_002195.png',
#   b'bufo_marinus_s_001243.png',
#   b'convertible_s_001433.png',
#   b'mule_deer_s_000628.png',
#   b'tabby_s_000410.png',
#   b'stud_s_000099.png',
#   b'passenger_ship_s_001530.png',
#   b'scow_s_000131.png',
#   b'tabby_s_001868.png',
#   b'bufo_bufo_s_002334.png',
#   b'bufo_viridis_s_000152.png',
#   b'passerine_s_001306.png',
#   b'house_cat_s_002116.png',
#   b'jetliner_s_001188.png',
#   b'moving_van_s_001359.png',
#   b'wapiti_s_000663.png',
#   b'felis_catus_s_000998.png',
#   b'sea_boat_s_001979.png',
#   b'fighter_aircraft_s_001776.png',
#   b'fighter_aircraft_s_001096.png',
#   b'shooting_brake_s_000774.png',
#   b'automobile_s_001310.png',
#   b'pekingese_s_001023.png',
#   b'american_elk_s_000455.png',
#   b'trucking_rig_s_001243.png',
#   b'house_cat_s_000877.png',
#   b'taxi_s_000040.png',
#   b'pilot_boat_s_001100.png',
#   b'articulated_lorry_s_000223.png',
#   b'felis_domesticus_s_000164.png',
#   b'trucking_rig_s_001300.png',
#   b'tractor_trailer_s_000254.png',
#   b'flightless_bird_s_000142.png',
#   b'dump_truck_s_000939.png',
#   b'deer_s_000967.png',
#   b'ship_s_001904.png',
#   b'wagtail_s_000309.png',
#   b'trailer_truck_s_000815.png',
#   b'container_ship_s_002477.png',
#   b'guard_boat_s_000285.png',
#   b'estate_car_s_000446.png',
#   b'puppy_s_001621.png',
#   b'tabby_cat_s_000689.png',
#   b'american_toad_s_000650.png',
#   b'boat_s_002381.png',
#   b'female_horse_s_000089.png',
#   b'bufo_viridis_s_001370.png',
#   b'ladder_truck_s_000044.png',
#   b'cargo_ship_s_001321.png',
#   b'twinjet_s_000547.png',
#   b'cascades_frog_s_000061.png',
#   b'odocoileus_hemionus_s_001017.png',
#   b'attack_aircraft_s_001254.png',
#   b'airplane_s_000006.png',
#   b'songbird_s_001232.png',
#   b'peke_s_000388.png',
#   b'boat_s_002143.png',
#   b'accentor_s_001182.png',
#   b'dive_bomber_s_001066.png',
#   b'dunnock_s_001650.png',
#   b'dawn_horse_s_001127.png',
#   b'european_toad_s_000359.png',
#   b'wrecker_s_002325.png',
#   b'lipizzan_s_000118.png',
#   b'automobile_s_000327.png',
#   b'pekinese_s_002027.png',
#   b'maltese_s_001913.png',
#   b'toad_frog_s_000836.png',
#   b'leopard_frog_s_001231.png',
#   b'domestic_cat_s_001066.png',
#   b'barking_frog_s_000840.png',
#   b'finch_s_000038.png',
#   b'capreolus_capreolus_s_000257.png',
#   b'lippizan_s_000126.png',
#   b'attack_aircraft_s_000089.png',
#   b'mutt_s_002278.png',
#   b'true_toad_s_000021.png',
#   b'capreolus_capreolus_s_000178.png',
#   b'bufo_viridis_s_000600.png',
#   b'chihuahua_s_000097.png',
#   b'meadow_pipit_s_001282.png',
#   b'red_deer_s_000008.png',
#   b'leopard_frog_s_001528.png',
#   b'estate_car_s_001220.png',
#   b'bullfrog_s_000408.png',
#   b'stealth_fighter_s_001637.png',
#   b'capreolus_capreolus_s_001669.png',
#   b'airbus_s_000736.png',
#   b'tabby_s_000292.png',
#   b'station_wagon_s_002793.png',
#   b'boat_s_000765.png',
#   b'english_toy_spaniel_s_000814.png',
#   b'european_elk_s_000265.png',
#   b'roe_deer_s_000371.png',
#   b'convertible_s_000414.png',
#   b'cow_pony_s_000145.png',
#   b'tabby_s_000126.png',
#   b'trucking_rig_s_001628.png',
#   b'muntjac_s_001738.png',
#   b'broodmare_s_000582.png',
#   b'fire_engine_s_001540.png',
#   b'gelding_s_000640.png',
#   b'tabby_cat_s_002533.png',
#   b'appaloosa_s_000342.png',
#   b'pipit_s_001066.png',
#   b'speedboat_s_000410.png',
#   b'roe_deer_s_001014.png',
#   b'american_toad_s_001815.png',
#   b'bufo_calamita_s_000773.png',
#   b'estate_car_s_000044.png',
#   b'cassowary_s_000021.png',
#   b'lorry_s_001709.png',
#   b'amphibious_aircraft_s_000141.png',
#   b'capreolus_capreolus_s_000073.png',
#   b'motorboat_s_000773.png',
#   b'lipizzan_s_001658.png',
#   b'tabby_cat_s_000531.png',
#   b'truck_s_000289.png',
#   b'speedboat_s_001711.png',
#   b'quarter_horse_s_000557.png',
#   b'quarter_horse_s_000942.png',
#   b'jumbo_jet_s_001476.png',
#   b'struthio_camelus_s_001197.png',
#   b'fallow_deer_s_001623.png',
#   b'compact_car_s_000850.png',
#   b'coupe_s_001912.png',
#   b'roe_deer_s_000678.png',
#   b'car_s_000674.png',
#   b'chihuahua_s_001937.png',
#   b'red_deer_s_002698.png',
#   b'jumbojet_s_001587.png',
#   b'toy_spaniel_s_001692.png',
#   b'rana_clamitans_s_000766.png',
#   b'pipit_s_000025.png',
#   b'cargo_vessel_s_001809.png',
#   b'pekingese_s_001613.png',
#   b'dive_bomber_s_000707.png',
#   b'lark_s_000550.png',
#   b'estate_car_s_000292.png',
#   b'tabby_cat_s_001853.png',
#   b'lapdog_s_001963.png',
#   b'palfrey_s_000300.png',
#   b'cat_s_002298.png',
#   b'mutt_s_000188.png',
#   b'police_cruiser_s_000471.png',
#   b'true_cat_s_001598.png',
#   b'peke_s_000638.png',
#   ...]}

# %%
data['meta'][b'label_names']
# Out:
# [b'airplane',
#  b'automobile',
#  b'bird',
#  b'cat',
#  b'deer',
#  b'dog',
#  b'frog',
#  b'horse',
#  b'ship',
#  b'truck']

# %%
try:
    random
except NameError:
    import random

target = data['train']['loaded'][f'data\\data_batch_{random.randint(1, 5)}']
targetIndex = random.randint(0, len(target[b'data']) - 1)
label = target[b'labels'][targetIndex]
label = f"{data['meta'][b'label_names'][label].decode('UTF-8')} ({label})"

showImg(
    target[b'data'][targetIndex].reshape(3, 32, 32).transpose(1, 2, 0),
    f"Label: {label}",
)

# %%
data['test']['loaded'][b'data']
# Out:
# array([[158, 159, 165, ..., 124, 129, 110],
#        [235, 231, 232, ..., 178, 191, 199],
#        [158, 158, 139, ...,   8,   3,   7],
#        ...,
#        [ 20,  19,  15, ...,  50,  53,  47],
#        [ 25,  15,  23, ...,  80,  81,  80],
#        [ 73,  98,  99, ...,  94,  58,  26]], dtype=uint8)

# %%
try:
    random
except NameError:
    import random

target = data['test']['loaded']
targetIndex = random.randint(0, len(target[b'data']) - 1)
label = target[b'labels'][targetIndex]
label = f"{data['meta'][b'label_names'][label].decode('UTF-8')} ({label})"

showImg(
    data['test']['loaded'][b'data'][targetIndex].reshape(3, 32, 32).transpose(1, 2, 0),
    f"Label: {label}"
)

# %% [markdown]
# ## Process
#
# Here begins the process which includes data splitting and pre-processing.

# %% [markdown]
# ### Pre Processing
#
# This also includes the splitting for validation data, effectively slashing the train data to 80% of its original 50k.

# %%
try:
    if ImageDataGenerator is None or random is None or train_test_split is None:
        raise NameError("ImageDataGenerator or random is not defined.")
except NameError:
    from tensorflow.keras.preprocessing.image import ImageDataGenerator
    from sklearn.model_selection import train_test_split
    import random

data['train']['processed'] = {
    'combined': {
        'data': None,
        'labels': None,
        'generator': None
    },
    'validation': {
        'data': None,
        'labels': None,
        'generator': None
    },
}

data['test']['processed'] = {
    'generator': None,
}

# Splitting the data into training and validation sets
x = []
y = []
for file in data['train']['loaded']:
    x.append(data['train']['loaded'][file][b'data'])
    y.append(data['train']['loaded'][file][b'labels'])
x_train, x_val, y_train, y_val = train_test_split(
    np.concatenate(x),
    np.concatenate(y),
    test_size = 0.2
)

#######################
### VALIDATION DATA ###
#######################
data['train']['processed']['validation']['data'] = x_val
data['train']['processed']['validation']['labels'] = y_val
data['train']['processed']['validation']['generator'] = (ImageDataGenerator(
    rescale = 1./255,
)).flow(
    data['train']['processed']['validation']['data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1),
    data['train']['processed']['validation']['labels'],
)

##################
### TRAIN DATA ###
##################
data['train']['processed']['combined']['data'] = x_train
data['train']['processed']['combined']['labels'] = y_train
data['train']['processed']['combined']['generator'] = (ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True
)).flow(
    data['train']['processed']['combined']['data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1),
    data['train']['processed']['combined']['labels'],
)


#################
### TEST DATA ###
#################
data['test']['processed']['generator'] = (ImageDataGenerator(
    rescale = 1./255,
)).flow(
    data['test']['loaded'][b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1),
    data['test']['loaded'][b'labels'],
)

# %% [markdown]
# ### Creating the Model

# %% [markdown]
# #### Neural Network

# %%
try:
    Sequential
except NameError:
    from tensorflow.keras.models import Sequential

model = Sequential()

# %% [markdown]
# #### Layers

# %%
try:
    if Dense is None or Conv2D is None or MaxPooling2D is None or Dropout is None or Flatten is None or ReLU is None or BatchNormalization is None:
        raise ImportError("Required modules not imported.")
except NameError or ImportError:
    from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, ReLU

# Input Layers
inputLayers = [
    # Start with 4 filters, 3x3 kernel, ReLU activation. Started with only 4
    # since the image is only 32x32. This allows the model to get low-level
    # features from the image.
    Conv2D(16, (3, 3), activation = 'relu', padding = 'same', input_shape = (32, 32, 3)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    # Middle with 8 filters, 3x3 kernel, ReLU activation
    # This allows the model to get mid-level features from the image.
    Conv2D(32, (3, 3), activation = 'relu', padding = 'same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    # End with 32 filters, 3x3 kernel, ReLU activation
    # This allows the model to get high-level features from the image.
    Conv2D(64, (3, 3), activation = 'relu', padding = 'same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    # Test if adding a new layer helps the model learn better.
    Conv2D(128, (3, 3), activation = 'relu', padding = 'same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
]

# Middle Layers (Including Hidden Layers)
middleLayers = [
    # Flatten the input to a 1D vector
    Flatten(),

    # Fully connected layer with 512 neurons and ReLU activation
    # This allows the model to learn complex features from the image.
    Dense(512, activation = 'relu'),

    # Dropout layer with >= 0.5 dropout rate
    # Note: If this layer is uncommented, that means the model underfitted.
    Dropout(0.5),

    # Dropout layer with < 0.5 dropout rate
    # Note: If this layer is uncommented, that means the model overfitted.
    # Dropout(0.4),
]

# Fully connected layer with 10 neurons (one for each class)
# Uses SoftMax since this is a multi-class classification problem
outputLayer = Dense(10, activation = 'softmax')

print(f"Input Layers: {len(inputLayers)}")
print(f"Middle Layers: {len(middleLayers)}")
print(f"Output Layers: {len([outputLayer])}")
print(f"All Layers: {len([*inputLayers, *middleLayers, outputLayer])}")
# Out:
# Input Layers: 12
# Middle Layers: 3
# Output Layers: 1
# All Layers: 16

# %% [markdown]
# #### Summary

# %%
for layer in [*inputLayers, *middleLayers, outputLayer]:
    model.add(layer)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 16)        448
#
#  batch_normalization_4 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        4640
#
#  batch_normalization_5 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 64)          18496
#
#  batch_normalization_6 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 128)         73856
#
#  batch_normalization_7 (Batc  (None, 4, 4, 128)        512
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 366,186
# Trainable params: 365,706
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# #### Compilation and Training

# %%
try:
    optimizers
except NameError:
    from tensorflow.keras import optimizers

model.compile(
    optimizer = optimizers.Adam(learning_rate = 1e-4),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy'],
    run_eagerly = True
)

# %%
# Steps per Epoch
# SPE = 250
SPE = len(data['train']['processed']['combined']['data']) // data['train']['processed']['combined']['generator'].batch_size
# Validation Steps
# VS = 100
VS = len(data['train']['processed']['validation']['data']) // data['train']['processed']['validation']['generator'].batch_size

print(f"Length: {len(data['train']['processed']['combined']['data'])} | Batch Size: {data['train']['processed']['combined']['generator'].batch_size}")
print(f"Steps per Epoch to Validation Steps: {SPE} - {VS}")

history = model.fit(
    data['train']['processed']['combined']['generator'],
    steps_per_epoch = SPE,
    epochs = 100,
    validation_data = data['train']['processed']['validation']['generator'],
    validation_steps = VS,
    verbose = 2,
    callbacks = callbacks,
)
# Out:
# Length: 40000 | Batch Size: 32
# Steps per Epoch to Validation Steps: 1250 - 312
# Epoch 1/100
# 1250/1250 - 120s - loss: 1.9696 - accuracy: 0.3102 - val_loss: 1.5534 - val_accuracy: 0.4396 - lr: 1.0000e-04 - 120s/epoch - 96ms/step
# Epoch 2/100
# 1250/1250 - 122s - loss: 1.6622 - accuracy: 0.3979 - val_loss: 1.4949 - val_accuracy: 0.4719 - lr: 1.0000e-04 - 122s/epoch - 98ms/step
# Epoch 3/100
# 1250/1250 - 134s - loss: 1.5640 - accuracy: 0.4344 - val_loss: 1.3111 - val_accuracy: 0.5211 - lr: 1.0000e-04 - 134s/epoch - 107ms/step
# Epoch 4/100
# 1250/1250 - 153s - loss: 1.4888 - accuracy: 0.4631 - val_loss: 1.2782 - val_accuracy: 0.5397 - lr: 1.0000e-04 - 153s/epoch - 123ms/step
# Epoch 5/100
# 1250/1250 - 119s - loss: 1.4316 - accuracy: 0.4837 - val_loss: 1.2477 - val_accuracy: 0.5523 - lr: 1.0000e-04 - 119s/epoch - 95ms/step
# Epoch 6/100
# 1250/1250 - 124s - loss: 1.3897 - accuracy: 0.4992 - val_loss: 1.2266 - val_accuracy: 0.5531 - lr: 1.0000e-04 - 124s/epoch - 99ms/step
# Epoch 7/100
# 1250/1250 - 122s - loss: 1.3485 - accuracy: 0.5162 - val_loss: 1.1879 - val_accuracy: 0.5703 - lr: 1.0000e-04 - 122s/epoch - 97ms/step
# Epoch 8/100
# 1250/1250 - 160s - loss: 1.3136 - accuracy: 0.5318 - val_loss: 1.1332 - val_accuracy: 0.5852 - lr: 1.0000e-04 - 160s/epoch - 128ms/step
# Epoch 9/100
# 1250/1250 - 122s - loss: 1.2956 - accuracy: 0.5382 - val_loss: 1.1154 - val_accuracy: 0.5984 - lr: 1.0000e-04 - 122s/epoch - 97ms/step
# Epoch 10/100
# 1250/1250 - 134s - loss: 1.2642 - accuracy: 0.5500 - val_loss: 1.1641 - val_accuracy: 0.5780 - lr: 1.0000e-04 - 134s/epoch - 107ms/step
# Epoch 11/100
# 1250/1250 - 138s - loss: 1.2307 - accuracy: 0.5604 - val_loss: 1.0436 - val_accuracy: 0.6216 - lr: 1.0000e-04 - 138s/epoch - 110ms/step
# Epoch 12/100
# 1250/1250 - 110s - loss: 1.2121 - accuracy: 0.5677 - val_loss: 0.9874 - val_accuracy: 0.6413 - lr: 1.0000e-04 - 110s/epoch - 88ms/step
# Epoch 13/100
# 1250/1250 - 176s - loss: 1.1940 - accuracy: 0.5749 - val_loss: 1.0146 - val_accuracy: 0.6343 - lr: 1.0000e-04 - 176s/epoch - 141ms/step
# Epoch 14/100
# 1250/1250 - 156s - loss: 1.1742 - accuracy: 0.5836 - val_loss: 1.0153 - val_accuracy: 0.6329 - lr: 1.0000e-04 - 156s/epoch - 125ms/step
# Epoch 15/100
# 1250/1250 - 194s - loss: 1.1491 - accuracy: 0.5938 - val_loss: 0.9730 - val_accuracy: 0.6466 - lr: 1.0000e-04 - 194s/epoch - 155ms/step
# Epoch 16/100
# 1250/1250 - 161s - loss: 1.1387 - accuracy: 0.5983 - val_loss: 0.9637 - val_accuracy: 0.6556 - lr: 1.0000e-04 - 161s/epoch - 129ms/step
# Epoch 17/100
# 1250/1250 - 123s - loss: 1.1260 - accuracy: 0.6002 - val_loss: 1.0548 - val_accuracy: 0.6209 - lr: 1.0000e-04 - 123s/epoch - 98ms/step
# Epoch 18/100
# 1250/1250 - 133s - loss: 1.1021 - accuracy: 0.6112 - val_loss: 0.9158 - val_accuracy: 0.6735 - lr: 1.0000e-04 - 133s/epoch - 106ms/step
# Epoch 19/100
# 1250/1250 - 118s - loss: 1.0921 - accuracy: 0.6125 - val_loss: 0.9237 - val_accuracy: 0.6734 - lr: 1.0000e-04 - 118s/epoch - 94ms/step
# Epoch 20/100
# 1250/1250 - 129s - loss: 1.0818 - accuracy: 0.6155 - val_loss: 0.9500 - val_accuracy: 0.6631 - lr: 1.0000e-04 - 129s/epoch - 103ms/step
# Epoch 21/100
# 1250/1250 - 124s - loss: 1.0656 - accuracy: 0.6222 - val_loss: 0.9210 - val_accuracy: 0.6760 - lr: 1.0000e-04 - 124s/epoch - 100ms/step
# Epoch 22/100
# 1250/1250 - 116s - loss: 1.0518 - accuracy: 0.6282 - val_loss: 0.9635 - val_accuracy: 0.6606 - lr: 1.0000e-04 - 116s/epoch - 93ms/step
# Epoch 23/100
# 1250/1250 - 97s - loss: 1.0385 - accuracy: 0.6311 - val_loss: 0.9000 - val_accuracy: 0.6755 - lr: 1.0000e-04 - 97s/epoch - 78ms/step
# Epoch 24/100
# 1250/1250 - 104s - loss: 1.0264 - accuracy: 0.6384 - val_loss: 0.9531 - val_accuracy: 0.6685 - lr: 1.0000e-04 - 104s/epoch - 83ms/step
# Epoch 25/100
# 1250/1250 - 92s - loss: 1.0225 - accuracy: 0.6392 - val_loss: 0.8869 - val_accuracy: 0.6844 - lr: 1.0000e-04 - 92s/epoch - 73ms/step
# Epoch 26/100
# 1250/1250 - 104s - loss: 1.0107 - accuracy: 0.6437 - val_loss: 0.8789 - val_accuracy: 0.6923 - lr: 1.0000e-04 - 104s/epoch - 83ms/step
# Epoch 27/100
# 1250/1250 - 107s - loss: 1.0045 - accuracy: 0.6438 - val_loss: 0.9578 - val_accuracy: 0.6735 - lr: 1.0000e-04 - 107s/epoch - 86ms/step
# Epoch 28/100
# 1250/1250 - 97s - loss: 0.9929 - accuracy: 0.6493 - val_loss: 0.9498 - val_accuracy: 0.6684 - lr: 1.0000e-04 - 97s/epoch - 78ms/step
# Epoch 29/100
# 1250/1250 - 92s - loss: 0.9904 - accuracy: 0.6505 - val_loss: 0.8448 - val_accuracy: 0.6982 - lr: 1.0000e-04 - 92s/epoch - 74ms/step
# Epoch 30/100
# 1250/1250 - 61s - loss: 0.9763 - accuracy: 0.6547 - val_loss: 0.8447 - val_accuracy: 0.7020 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 31/100
# 1250/1250 - 62s - loss: 0.9734 - accuracy: 0.6565 - val_loss: 0.9329 - val_accuracy: 0.6745 - lr: 1.0000e-04 - 62s/epoch - 49ms/step
# Epoch 32/100
# 1250/1250 - 62s - loss: 0.9605 - accuracy: 0.6611 - val_loss: 0.8276 - val_accuracy: 0.7095 - lr: 1.0000e-04 - 62s/epoch - 50ms/step
# Epoch 33/100
# 1250/1250 - 61s - loss: 0.9491 - accuracy: 0.6662 - val_loss: 0.8152 - val_accuracy: 0.7139 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 34/100
# 1250/1250 - 60s - loss: 0.9361 - accuracy: 0.6734 - val_loss: 0.8245 - val_accuracy: 0.7125 - lr: 1.0000e-04 - 60s/epoch - 48ms/step
# Epoch 35/100
# 1250/1250 - 61s - loss: 0.9382 - accuracy: 0.6678 - val_loss: 0.9556 - val_accuracy: 0.6820 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 36/100
# 1250/1250 - 62s - loss: 0.9369 - accuracy: 0.6704 - val_loss: 0.8129 - val_accuracy: 0.7155 - lr: 1.0000e-04 - 62s/epoch - 49ms/step
# Epoch 37/100
# 1250/1250 - 59s - loss: 0.9255 - accuracy: 0.6742 - val_loss: 0.8231 - val_accuracy: 0.7158 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 38/100
# 1250/1250 - 62s - loss: 0.9154 - accuracy: 0.6782 - val_loss: 0.8204 - val_accuracy: 0.7155 - lr: 1.0000e-04 - 62s/epoch - 49ms/step
# Epoch 39/100
# 1250/1250 - 60s - loss: 0.9094 - accuracy: 0.6790 - val_loss: 0.8428 - val_accuracy: 0.7135 - lr: 1.0000e-04 - 60s/epoch - 48ms/step
# Epoch 40/100
# 1250/1250 - 60s - loss: 0.9001 - accuracy: 0.6836 - val_loss: 0.8874 - val_accuracy: 0.6973 - lr: 1.0000e-04 - 60s/epoch - 48ms/step
# Epoch 41/100
# 1250/1250 - 61s - loss: 0.9007 - accuracy: 0.6836 - val_loss: 0.8109 - val_accuracy: 0.7206 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 42/100
# 1250/1250 - 60s - loss: 0.8972 - accuracy: 0.6836 - val_loss: 0.7830 - val_accuracy: 0.7254 - lr: 1.0000e-04 - 60s/epoch - 48ms/step
# Epoch 43/100
# 1250/1250 - 59s - loss: 0.8875 - accuracy: 0.6909 - val_loss: 0.8022 - val_accuracy: 0.7274 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 44/100
# 1250/1250 - 60s - loss: 0.8854 - accuracy: 0.6915 - val_loss: 0.7659 - val_accuracy: 0.7339 - lr: 1.0000e-04 - 60s/epoch - 48ms/step
# Epoch 45/100
# 1250/1250 - 59s - loss: 0.8776 - accuracy: 0.6902 - val_loss: 0.7620 - val_accuracy: 0.7367 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 46/100
# 1250/1250 - 59s - loss: 0.8709 - accuracy: 0.6951 - val_loss: 0.7950 - val_accuracy: 0.7327 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 47/100
# 1250/1250 - 61s - loss: 0.8681 - accuracy: 0.6963 - val_loss: 0.8095 - val_accuracy: 0.7260 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 48/100
# 1250/1250 - 59s - loss: 0.8634 - accuracy: 0.6941 - val_loss: 0.7622 - val_accuracy: 0.7392 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 49/100
# 1250/1250 - 59s - loss: 0.8542 - accuracy: 0.7003 - val_loss: 0.7462 - val_accuracy: 0.7427 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 50/100
# 1250/1250 - 61s - loss: 0.8521 - accuracy: 0.6990 - val_loss: 0.7729 - val_accuracy: 0.7355 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 51/100
# 1250/1250 - 59s - loss: 0.8500 - accuracy: 0.7045 - val_loss: 0.7643 - val_accuracy: 0.7328 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 52/100
# 1250/1250 - 61s - loss: 0.8446 - accuracy: 0.7043 - val_loss: 0.7146 - val_accuracy: 0.7528 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 53/100
# 1250/1250 - 61s - loss: 0.8440 - accuracy: 0.7040 - val_loss: 0.7218 - val_accuracy: 0.7496 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 54/100
# 1250/1250 - 59s - loss: 0.8430 - accuracy: 0.7064 - val_loss: 0.7418 - val_accuracy: 0.7500 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 55/100
# 1250/1250 - 59s - loss: 0.8335 - accuracy: 0.7056 - val_loss: 0.7158 - val_accuracy: 0.7539 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 56/100
# 1250/1250 - 61s - loss: 0.8335 - accuracy: 0.7103 - val_loss: 0.7285 - val_accuracy: 0.7517 - lr: 1.0000e-04 - 61s/epoch - 49ms/step
# Epoch 57/100
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1250/1250 - 59s - loss: 0.8235 - accuracy: 0.7120 - val_loss: 0.7261 - val_accuracy: 0.7492 - lr: 1.0000e-04 - 59s/epoch - 47ms/step
# Epoch 58/100
# 1250/1250 - 59s - loss: 0.8097 - accuracy: 0.7153 - val_loss: 0.7080 - val_accuracy: 0.7542 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 59/100
# 1250/1250 - 62s - loss: 0.8062 - accuracy: 0.7171 - val_loss: 0.7174 - val_accuracy: 0.7520 - lr: 5.0000e-05 - 62s/epoch - 49ms/step
# Epoch 60/100
# 1250/1250 - 59s - loss: 0.7913 - accuracy: 0.7210 - val_loss: 0.7164 - val_accuracy: 0.7577 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 61/100
# 1250/1250 - 59s - loss: 0.7974 - accuracy: 0.7193 - val_loss: 0.6924 - val_accuracy: 0.7637 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 62/100
# 1250/1250 - 61s - loss: 0.7933 - accuracy: 0.7221 - val_loss: 0.7201 - val_accuracy: 0.7542 - lr: 5.0000e-05 - 61s/epoch - 49ms/step
# Epoch 63/100
# 1250/1250 - 59s - loss: 0.7817 - accuracy: 0.7272 - val_loss: 0.7363 - val_accuracy: 0.7465 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 64/100
# 1250/1250 - 61s - loss: 0.7862 - accuracy: 0.7252 - val_loss: 0.6731 - val_accuracy: 0.7686 - lr: 5.0000e-05 - 61s/epoch - 49ms/step
# Epoch 65/100
# 1250/1250 - 61s - loss: 0.7834 - accuracy: 0.7258 - val_loss: 0.7234 - val_accuracy: 0.7528 - lr: 5.0000e-05 - 61s/epoch - 48ms/step
# Epoch 66/100
# 1250/1250 - 59s - loss: 0.7838 - accuracy: 0.7262 - val_loss: 0.7322 - val_accuracy: 0.7514 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 67/100
# 1250/1250 - 59s - loss: 0.7801 - accuracy: 0.7276 - val_loss: 0.6468 - val_accuracy: 0.7718 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 68/100
# 1250/1250 - 61s - loss: 0.7731 - accuracy: 0.7315 - val_loss: 0.6816 - val_accuracy: 0.7665 - lr: 5.0000e-05 - 61s/epoch - 48ms/step
# Epoch 69/100
# 1250/1250 - 62s - loss: 0.7709 - accuracy: 0.7279 - val_loss: 0.6821 - val_accuracy: 0.7693 - lr: 5.0000e-05 - 62s/epoch - 49ms/step
# Epoch 70/100
# 1250/1250 - 61s - loss: 0.7730 - accuracy: 0.7290 - val_loss: 0.6566 - val_accuracy: 0.7743 - lr: 5.0000e-05 - 61s/epoch - 49ms/step
# Epoch 71/100
# 1250/1250 - 60s - loss: 0.7702 - accuracy: 0.7305 - val_loss: 0.6915 - val_accuracy: 0.7685 - lr: 5.0000e-05 - 60s/epoch - 48ms/step
# Epoch 72/100
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1250/1250 - 59s - loss: 0.7635 - accuracy: 0.7307 - val_loss: 0.6779 - val_accuracy: 0.7717 - lr: 5.0000e-05 - 59s/epoch - 47ms/step
# Epoch 73/100
# 1250/1250 - 61s - loss: 0.7572 - accuracy: 0.7373 - val_loss: 0.6864 - val_accuracy: 0.7675 - lr: 2.5000e-05 - 61s/epoch - 49ms/step
# Epoch 74/100
# 1250/1250 - 62s - loss: 0.7624 - accuracy: 0.7350 - val_loss: 0.6474 - val_accuracy: 0.7756 - lr: 2.5000e-05 - 62s/epoch - 49ms/step
# Epoch 75/100
# 1250/1250 - 60s - loss: 0.7576 - accuracy: 0.7344 - val_loss: 0.6628 - val_accuracy: 0.7750 - lr: 2.5000e-05 - 60s/epoch - 48ms/step
# Epoch 76/100
# 1250/1250 - 58s - loss: 0.7498 - accuracy: 0.7396 - val_loss: 0.6601 - val_accuracy: 0.7728 - lr: 2.5000e-05 - 58s/epoch - 47ms/step
# Epoch 77/100
# Restoring model weights from the end of the best epoch: 67.
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1250/1250 - 60s - loss: 0.7509 - accuracy: 0.7390 - val_loss: 0.6807 - val_accuracy: 0.7713 - lr: 2.5000e-05 - 60s/epoch - 48ms/step
# Epoch 77: early stopping

# %% [markdown]
# ## Prediction
#
# Test the model's prediction

# %%
from copy import copy
try:
    np
except NameError:
    import numpy as np

generator = copy(data['test']['processed']['generator'])
min = 0
max = 0
avg = 0
logPerBatch = False

forCM = {
    'y_true': [],
    'y_pred': [],
}

for i in range(len(generator)):
    images, labels = generator[i]

    classes = model.predict(images, verbose = 0)
    classes = np.argmax(classes, axis = 1)

    forCM['y_true'].extend(labels)
    forCM['y_pred'].extend(classes)

    if logPerBatch:
        print(f"Classes: {classes}")
        print(f"Labels: {labels}")

    # Accuracy
    accuracy = np.sum(classes == labels) / len(labels)
    if accuracy > max:
        max = accuracy
    if accuracy < min or min == 0:
        min = accuracy
    avg += accuracy

    if logPerBatch:
        print(f"Formula: {np.sum(classes == labels)} / {len(labels)}")
        print(f"Accuracy: {accuracy * 100:.2f}%")
        print(f"Of {len(labels)} images, {np.sum(classes == labels)} were correct while {np.sum(classes != labels)} were incorrect.")

avg /= len(generator)

# Accuracy Range
print(f"Accuracy: {avg * 100:.2f}%")
print(f"Accuracy Range: {min * 100:.2f}% - {max * 100:.2f}%")
print(f"Optimizer used is {model.optimizer.get_config()['name']} with a learning rate of {model.optimizer.learning_rate.numpy()}")
# Out:
# Accuracy: 76.68%
# Accuracy Range: 53.12% - 96.88%
# Optimizer used is Adam with a learning rate of 1.249999968422344e-05

# %% [markdown]
# ## Model and Metrics Visualization

# %% [markdown]
# ### Accuracy

# %%
try:
    if datetime is None or sns is None or plt is None or np is None:
        raise ImportError("datetime or sns module not found")
except NameError:
    import datetime
    import matplotlib.pyplot as plt
    import numpy as np
    import seaborn as sns

_, accuracy = model.evaluate(
    data['test']['processed']['generator'],
    verbose = 2
)
status = "Underfitted" if accuracy < 0.5 else "Overfitted" if accuracy > 0.9 else "Just Right"
yTrue = np.sum(np.array(forCM['y_true']) == np.array(forCM['y_pred']))
yLength = len(forCM['y_pred'])
yScore = yTrue / yLength

accuracy = accuracy * 100
unixTime = int(datetime.datetime.now().timestamp() * 1e6)

print(f"Accuracy: {accuracy:.2f}%")
print(f"Using `forCM`: {yTrue} / {yLength} = {yScore * 100:.2f}%")

plt.figure(figsize = (10, 6))
plt.plot(history.history['accuracy'], color = 'blue', label = 'train')
plt.plot(history.history['val_accuracy'], color = 'red', label = 'val')
plt.legend()
plt.grid()
plt.title(f'Accuracy ({model.optimizer.get_config()["name"]})\nStatus: {status} ({accuracy:.2f}%)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.savefig(f"outputs/accuracy{unixTime} - {accuracy:.2f}%.png")
# Out:
# 313/313 - 6s - loss: 0.6785 - accuracy: 0.7671 - 6s/epoch - 18ms/step
# Accuracy: 76.71%
# Using `forCM`: 7671 / 10000 = 76.71%

# %% [markdown]
# ### Confusion Matrix

# %%
try:
    if confusion_matrix is None or sns is None or plt is None or os is None or datetime is None:
        raise ImportError("Required modules not imported.")
except NameError:
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt
    import os
    import seaborn as sns

cm = confusion_matrix(
    forCM['y_true'],
    forCM['y_pred'],
)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot = True, fmt = 'd', cmap = 'Blues')

plt.title(f'Confusion Matrix ({model.optimizer.get_config()["name"]})\nStatus: {status} ({accuracy:.2f}%)')
plt.xlabel('Predicted')
plt.ylabel('Actual')

if not os.path.exists('outputs'):
    os.makedirs('outputs')

plt.savefig(f'outputs/confusion_matrix{unixTime} - {accuracy:.2f}%.png')

# %% [markdown]
# ### Model Visualization

# %%
plot_model(model, to_file=f'outputs/model{unixTime} - {accuracy:.2f}%.png', show_shapes=True)
